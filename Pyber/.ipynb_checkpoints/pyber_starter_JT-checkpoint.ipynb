# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
ride_data = pd.read_csv(ride_data_to_load)
# Combine the data into a single dataset
df = pd.DataFrame.merge(ride_data, city_data, on = 'city', how = 'left')
# Display the data table for preview
df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
# Build the scatter plots for each city types
# Incorporate the other graph properties
# Create a legend
# Incorporate a text label regarding circle size
# Save Figure
# ----------------------------------------------

# group by city name
grp_city = df.groupby('city')

# average fare
avg_fare = grp_city.mean()['fare']

# number of rides
ride_count = grp_city['ride_id'].count()

# number of drivers
driver_count = grp_city.mean()['driver_count']

# city type data
city_type = city_data.set_index('city')['type']

# city df
city_info = pd.DataFrame({
    "Number of Rides": ride_count,
    "Average Fare": avg_fare,
    "Number of Drivers": driver_count,
    "Type of City": city_type
})

city_info.sort_values('Number of Drivers', ascending = False)

# df by city type
rural = city_info[city_info['Type of City'] == 'Rural']
suburban = city_info[city_info['Type of City'] == 'Suburban']
urban = city_info[city_info['Type of City'] == 'Urban']

# set colors
set_color = {'Rural' : 'yellow', 'Suburban' : 'skyblue', 'Urban' : 'salmon'}

# scatter plots for each city type
plt.scatter(rural['Number of Rides'], rural['Average Fare'], s = rural['Number of Drivers']*10, color = set_color['Rural'], edgecolor = 'black', label = 'Rural', alpha = .75)
plt.scatter(suburban['Number of Rides'], suburban['Average Fare'], s = suburban['Number of Drivers']*10, color = set_color['Suburban'], edgecolor = 'black', label = 'Suburban', alpha = .75)
plt.scatter(urban['Number of Rides'], urban['Average Fare'], s = urban['Number of Drivers']*10, color = set_color['Urban'], edgecolor = 'black', label = 'Urban', alpha = .75)

legend = plt.legend(frameon = True, edgecolor = 'black')
legend.legendHandles[0]._sizes = [50]
legend.legendHandles[1]._sizes = [50]
legend.legendHandles[2]._sizes = [50]


plt.title('Note:Size of Bubble Corresponds to Number of Drivers per City')
plt.xlabel('Number of Rides per City')
plt.ylabel('Average Fare per City')

plt.grid = True

# %%
# Show plot
plt.show()

# save figure
plt.savefig("01_bubble_plot_JT.png")

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
grp_type = df.groupby('type')['type', 'fare', 'ride_id', 'driver_count']
total_fare = grp_type.sum()['fare']
# Build Pie Chart
labels = total_fare.index
explode = [0 , 0, .1]
colors = [set_color[n] for n in labels]
plt.pie(total_fare, startangle = 270, colors = colors, explode = explode, labels = labels, autopct = "%1.2f%%", shadow = True)
legend = plt.legend(frameon = True, edgecolor = 'black', loc = 'lower right')
legend.legendHandles[0]._sizes = [50]
legend.legendHandles[1]._sizes = [50]
legend.legendHandles[2]._sizes = [50]
plt.axis('equal')
plt.title("% of Total Fares By City");
# Save Figure
plt.savefig("02_scatter_plot_JT.png")

# %%
# Show Figure
# plt.title('% of Total Fares by City Type')
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
total_ride = grp_type.count()['ride_id']
# Build Pie Chart
labels = total_ride.index
explode = [0 , 0, .1]
colors = [set_color[n] for n in labels]
plt.pie(total_fare, startangle = 270, colors = colors, explode = explode, labels = labels, autopct = "%1.2f%%", shadow = True)
legend = plt.legend(frameon = True, edgecolor = 'black', loc = 'lower right')
legend.legendHandles[0]._sizes = [50]
legend.legendHandles[1]._sizes = [50]
legend.legendHandles[2]._sizes = [50]
plt.axis('equal')
plt.title("% of Total Rides By City Type");
# Save Figure
plt.savefig("03_scatter_plot_JT.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
total_driver = city_data.groupby('type').sum()['driver_count']
# Build Pie Charts
labels = total_driver.index
explode = [0 , 0, .1]
colors = [set_color[n] for n in labels]
plt.pie(total_fare, startangle = 270, colors = colors, explode = explode, labels = labels, autopct = "%1.2f%%", shadow = True)
legend = plt.legend(frameon = True, edgecolor = 'black', loc = 'lower right')
legend.legendHandles[0]._sizes = [50]
legend.legendHandles[1]._sizes = [50]
legend.legendHandles[2]._sizes = [50]
plt.axis('equal')
plt.title("% of Total Drivers By City Type");
# Save Figure
plt.savefig("04_scatter_plot_JT.png")

# %%
# Show Figure
plt.show()
